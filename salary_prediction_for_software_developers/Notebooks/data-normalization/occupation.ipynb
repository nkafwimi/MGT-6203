# %%
import pandas as pd
import numpy as np

# %%
master_df = pd.read_csv("../../Data/filtered/master-data.csv", sep = ",", encoding = "Latin-1")

# %%
master_df["occupation"] = master_df["occupation"].str.split(";", expand = True).fillna("null")[0] + " & " + master_df["occupation"].str.split(";", expand = True).fillna("null")[1]

# %%
master_df["occupation"].unique()
# Out:
# array(['Executive (VP of Eng, CTO, CIO, etc.) & null',
#        'Web Application Developer & null',
#        'Desktop Application Developer & null',
#        'IT Staff / System Administrator & null',
#        'Database Administrator & null', 'Server Programmer & null',
#        'Manager of Developers or Team Leader & null', 'Other & null',
#        'Student & null', 'Embedded Application Developer & null',
#        'Kernel / Driver Developer & null', 'Systems Analyst & null',
#        'IT Manager & null', "I don't work in tech & null",
#        'Enterprise Level Services & null',
#        'Back-End Web Developer & null', 'Full-Stack Web Developer & null',
#        'Desktop Software Developer & null',
#        'Mobile Application Developer & null',
#        'Front-End Web Developer & null', 'DevOps & null',
#        'Back-end web developer & null',
#        'Business intelligence or data warehousing expert & null',
#        'Data scientist & null', 'Database administrator & null',
# ...
