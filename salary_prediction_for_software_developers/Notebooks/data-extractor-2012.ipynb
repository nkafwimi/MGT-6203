# %% [markdown]
# This notebook is used to extractor the necessary data for Salary Prediction from 2012 Stack Overflow Annual Developer Survey
#
# https://insights.stackoverflow.com/survey

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# NOTE: Make sure **Data/source/** folder has the survey data downloaded using **Scripts/download_survey_data.py --all** script

# %% [markdown]
# ### 2012 Stack Overflow User Survey

# %%
survey_res = pd.read_csv("../Data/source/2012.csv", sep=",", encoding='Latin-1')

# %%
print(f"Number of responses to the survey in 2012: {survey_res.shape[0]-1}")
# Out:
# Number of responses to the survey in 2012: 6243

# %%
survey_res = survey_res.drop(0)
survey_res.head()
# Out:
#   What Country or Region do you live in?  \
# 1                                  India
# 2                                Germany
# 3                         United Kingdom
# 4                                 France
# 5               United States of America
#
#   Which US State or Territory do you live in? How old are you?  \
# 1                                         NaN            20-24
# 2                                         NaN            25-29
# 3                                         NaN            20-24
# 4                                         NaN            20-24
# 5                                        Iowa             < 20
#
#   How many years of IT/Programming experience do you have?  \
# 1                                                 <2
# 2                                                 <2
# 3                                              41070
# 4                                              40944
# 5                                              40944
#
#   How would you best describe the industry you currently work in?  \
# 1                                         Consulting
# 2                                              Other
# 3                                  Finance / Banking
# 4                                  Software Products
# 5                                              Other
#
#   Which best describes the size of your company?  \
# 1                          Fortune 1000 (1,000+)
# 2                 Mature Small Business (25-100)
# 3                 Mature Small Business (25-100)
# 4                 Mature Small Business (25-100)
# 5                                        Student
#
#   Which of the following best describes your occupation?  \
# 1                                  Server Programmer
# 2                     Embedded Application Developer
# 3                          Web Application Developer
# 4                     Embedded Application Developer
# 5                                            Student
#
#   What is your involvement in purchasing products or services for the company you work for? (You can choose more than one)  \
# 1                                         Influencer
# 2                                                NaN
# 3                                         Influencer
# 4                                                NaN
# 5                                                NaN
#
#     Unnamed: 8 Unnamed: 9  ...  \
# 1  Recommender        NaN  ...
# 2  Recommender        NaN  ...
# 3  Recommender        NaN  ...
# 4          NaN        NaN  ...
# 5          NaN        NaN  ...
#
#   Please rate the advertising you've seen on Stack Overflow  \
# 1                                                NaN
# 2                                            Neutral
# 3                                            Neutral
# 4                                              Agree
# 5                                            Neutral
#
#          Unnamed: 66 Unnamed: 67        Unnamed: 68        Unnamed: 69  \
# 1                NaN         NaN                NaN                NaN
# 2              Agree       Agree  Strongly Disagree  Strongly Disagree
# 3            Neutral     Neutral            Neutral            Neutral
# 4  Strongly Disagree    Disagree           Disagree  Strongly Disagree
# 5            Neutral     Neutral            Neutral  Strongly Disagree
#
#       Unnamed: 70 What advertisers do you remember seeing on Stack Overflow?  \
# 1             NaN                                                NaN
# 2        Disagree                                                NaN
# 3  Strongly Agree                                                NaN
# 4        Disagree                                             None !
# 5  Strongly Agree                                               none
#
#   What is your current Stack Overflow reputation?  \
# 1                                             NaN
# 2                           Don't have an account
# 3                                               1
# 4                           Don't have an account
# 5                                               1
#
#   Which of our sites do you frequent most? Unnamed: 74
# 1                                      NaN         NaN
# 2                           Stack Overflow         NaN
# 3                           Stack Overflow         NaN
# 4                           Stack Overflow         NaN
# 5                           Stack Overflow         NaN
#
# [5 rows x 75 columns]

# %%
# Extract the Country 

survey_res_flt = pd.DataFrame()
survey_res_flt["country"] = survey_res["What Country or Region do you live in?"]

# Extract Age
survey_res_flt["age"] = survey_res["How old are you?"]

# Extract years of IT/programing experience
survey_res_flt["IT_experience_in_years"] = survey_res["How many years of IT/Programming experience do you have?"]

# Extract industry 
survey_res_flt["industry"] = survey_res["How would you best describe the industry you currently work in?"]

# Extract company size 
survey_res_flt["company_size"] = survey_res["Which best describes the size of your company?"]

# Extract occupation 
survey_res_flt["occupation"] = survey_res["Which of the following best describes your occupation?"]

# Extract Current project details
survey_res_flt["current_development_project"] = survey_res["What type of project are you developing?"]

# %%
# Extract programming language 

language_col_start = survey_res.columns.get_loc("Which languages are you proficient in?")

survey_res_flt["proficient_languages"] = (
    survey_res
    .iloc[:, language_col_start+1:language_col_start+15]
    .apply(lambda x: ",".join(x.astype(str)), axis = 1)
)

survey_res_flt["proficient_languages"] = [[pl for pl in pl_list.split(',') if pl != 'nan'] for pl_list in survey_res_flt['proficient_languages'].values.tolist()]

# %%
# Extract the desktop operating system used 
survey_res_flt["desktop_OS"] = survey_res["Which desktop operating system do you use the most?"]

# Extract job satisfaction 
survey_res_flt["job_satisfaction"] = survey_res["What best describes your career / job satisfaction? "]

# Extract compensation
survey_res_flt["compensation"] = survey_res["Including bonus, what is your annual compensation in USD?"]

# %%
# Extract Product technology
product_tech_col_start = survey_res.columns.get_loc("Which technology products do you own? (You can choose more than one)")

survey_res_flt["product_technology"] = (
    survey_res
    .iloc[:, product_tech_col_start+1:product_tech_col_start+20]
    .apply(lambda x: ",".join(x.astype(str)), axis = 1)
)

survey_res_flt["product_technology"] = [[pt for pt in pt_list.split(',') if pt != 'nan'] for pt_list in survey_res_flt['product_technology'].values.tolist()]

# %%
# Extract stackoverflow reputation 
survey_res_flt["stackoverflow_reputation"] = survey_res["What is your current Stack Overflow reputation?"]

# %%
survey_res_flt.head()
# Out:
#                     country    age IT_experience_in_years           industry  \
# 1                     India  20-24                     <2         Consulting
# 2                   Germany  25-29                     <2              Other
# 3            United Kingdom  20-24                  41070  Finance / Banking
# 4                    France  20-24                  40944  Software Products
# 5  United States of America   < 20                  40944              Other
#
#                      company_size                      occupation  \
# 1           Fortune 1000 (1,000+)               Server Programmer
# 2  Mature Small Business (25-100)  Embedded Application Developer
# 3  Mature Small Business (25-100)       Web Application Developer
# 4  Mature Small Business (25-100)  Embedded Application Developer
# 5                         Student                         Student
#
#   current_development_project  \
# 1                        SaaS
# 2                      Mobile
# 3                Web Platform
# 4                      Mobile
# 5                      Mobile
#
#                               proficient_languages desktop_OS  \
# 1                        [JavaScript, SQL, C++, C]      Linux
# 2  [JavaScript, CSS, PHP, Objective-C, C++, HTML5]  Windows 7
# 3              [CSS, PHP, Objective-C, SQL, HTML5]   Mac OS X
# 4                                            [C++]      Linux
# 5                                               []   Mac OS X
#
#           job_satisfaction          compensation  \
# 1              Love my job              <$20,000
# 2    I enjoy going to work     $20,000 - $40,000
# 3    I enjoy going to work     $20,000 - $40,000
# 4  I'm not happy in my job     $20,000 - $40,000
# 5      I wish I had a job!  Student / Unemployed
#
#                                   product_technology stackoverflow_reputation
# 1                                 [Android, Netbook]                      NaN
# 2                                                 []    Don't have an account
# 3  [Blackberry, Other media streaming device, Xbo...                        1
# 4                                    [Android, iPad]    Don't have an account
# 5             [Android, Kindle, Other gaming system]                        1

# %%
survey_res_flt.to_csv("../Data/filtered/2012.csv", index=False)
