# %% [markdown]
# This notebook is used to extractor the necessary data for Salary Prediction from 2018 Stack Overflow Annual Developer Survey
#
# https://insights.stackoverflow.com/survey

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# NOTE: Make sure **Data/source/** folder has the survey data downloaded using **Scripts/download_survey_data.py --all** script

# %% [markdown]
# ### 2018 Stack Overflow User Survey

# %%
survey_res = pd.read_csv("../../Data/source/2018.csv", sep=",", encoding='Latin-1', low_memory=False)

# %%
print(f"Number of responses to the survey in 2018: {survey_res.shape[0]}")
# Out:
# Number of responses to the survey in 2018: 98855

# %%
survey_res.head()
# Out:
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType  ...  \
# 0                               Full-stack developer  ...
# 1  Database administrator;DevOps specialist;Full-...  ...
# 2           Engineering manager;Full-stack developer  ...
# 3                               Full-stack developer  ...
# 4  Data or business analyst;Desktop or enterprise...  ...
#
#                      Exercise Gender         SexualOrientation  \
# 0        3 - 4 times per week   Male  Straight or heterosexual
# 1   Daily or almost every day   Male  Straight or heterosexual
# 2                         NaN    NaN                       NaN
# 3  I don't typically exercise   Male  Straight or heterosexual
# 4        3 - 4 times per week   Male  Straight or heterosexual
#
#                                     EducationParents  \
# 0         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 1         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 2                                                NaN
# 3  Some college/university study without earning ...
# 4  Some college/university study without earning ...
#
#                   RaceEthnicity                Age Dependents  MilitaryUS  \
# 0   Black or of African descent  25 - 34 years old        Yes         NaN
# 1  White or of European descent  35 - 44 years old        Yes         NaN
# 2                           NaN                NaN        NaN         NaN
# 3  White or of European descent  35 - 44 years old         No          No
# 4  White or of European descent  18 - 24 years old        Yes         NaN
#
#                           SurveyTooLong     SurveyEasy
# 0  The survey was an appropriate length      Very easy
# 1  The survey was an appropriate length  Somewhat easy
# 2                                   NaN            NaN
# 3  The survey was an appropriate length  Somewhat easy
# 4  The survey was an appropriate length  Somewhat easy
#
# [5 rows x 129 columns]

# %%
# Extract the Country 
survey_res_flt = pd.DataFrame()
survey_res_flt["country"] = survey_res["Country"]

# Extract student information 
survey_res_flt["student"] = survey_res["Student"]

# Extract employment status
survey_res_flt["employment_status"] = survey_res["Employment"]

# Extract employment status
survey_res_flt["formal_education"] = survey_res["FormalEducation"]

# Extract company size ~ Number of developers
survey_res_flt["company_size"] = survey_res["CompanySize"]

# Extract occupation 
survey_res_flt["occupation"] = survey_res["DevType"]

# Extract years of IT/programing experience
survey_res_flt["IT_experience_in_years"] = survey_res["YearsCodingProf"]

# Extract job satisfaction 
survey_res_flt["job_satisfaction"] = survey_res["JobSatisfaction"]

# Extract compensation
survey_res_flt["compensation"] = survey_res["ConvertedSalary"]

# Extract programming language/technology 
survey_res_flt["proficient_languages"] = survey_res["LanguageWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract programming language/technology 
survey_res_flt["database_worked_on"] = survey_res["DatabaseWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract programming language/technology 
survey_res_flt["platform_worked_on"] = survey_res["PlatformWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract programming language/technology 
survey_res_flt["framework_worked_on"] = survey_res["FrameworkWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract the desktop operating system used 
survey_res_flt["desktop_OS"] = survey_res["OperatingSystem"]

# Extract time spent on work 
survey_res_flt["work_hours"] = survey_res["HoursComputer"]

# Extract Age
survey_res_flt["age"] = survey_res["Age"]

#Extract gender
survey_res_flt["gender"] = survey_res["Gender"]

# %%
# Extract stackoverflow reputation 
survey_res_flt["stackoverflow_account_holder"] = survey_res["StackOverflowHasAccount"]

# Extract stackoverflow reputation 
survey_res_flt["stackoverflow_participation"] = survey_res["StackOverflowParticipate"]

# %%
survey_res_flt.head()
# Out:
#           country         student   employment_status  \
# 0           Kenya              No  Employed part-time
# 1  United Kingdom              No  Employed full-time
# 2   United States              No  Employed full-time
# 3   United States              No  Employed full-time
# 4    South Africa  Yes, part-time  Employed full-time
#
#                                     formal_education  \
# 0         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 1         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 2                                   Associate degree
# 3         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 4  Some college/university study without earning ...
#
#                company_size  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                           occupation IT_experience_in_years  \
# 0                               Full-stack developer              3-5 years
# 1  Database administrator;DevOps specialist;Full-...            18-20 years
# 2           Engineering manager;Full-stack developer              6-8 years
# 3                               Full-stack developer            12-14 years
# 4  Data or business analyst;Desktop or enterprise...              0-2 years
#
#                      job_satisfaction  compensation  \
# 0                 Extremely satisfied           NaN
# 1             Moderately dissatisfied       70841.0
# 2                Moderately satisfied           NaN
# 3  Neither satisfied nor dissatisfied           NaN
# 4                  Slightly satisfied       21426.0
#
#                                 proficient_languages  \
# 0                    [JavaScript, Python, HTML, CSS]
# 1                   [JavaScript, Python, Bash/Shell]
# 2                                                NaN
# 3  [C#, JavaScript, SQL, TypeScript, HTML, CSS, B...
# 4         [C, C++, Java, Matlab, R, SQL, Bash/Shell]
#
#                                   database_worked_on  \
# 0  [Redis, SQL Server, MySQL, PostgreSQL, Amazon ...
# 1                     [Redis, PostgreSQL, Memcached]
# 2                                                NaN
# 3  [SQL Server, Microsoft Azure (Tables, CosmosDB...
# 4          [SQL Server, PostgreSQL, Oracle, IBM Db2]
#
#                      platform_worked_on framework_worked_on   desktop_OS  \
# 0         [AWS, Azure, Linux, Firebase]     [Django, React]  Linux-based
# 1                               [Linux]            [Django]  Linux-based
# 2                                   NaN                 NaN          NaN
# 3                               [Azure]                 NaN      Windows
# 4  [Arduino, Windows Desktop or Server]                 NaN      Windows
#
#       work_hours                age gender stackoverflow_account_holder  \
# 0   9 - 12 hours  25 - 34 years old   Male                          Yes
# 1    5 - 8 hours  35 - 44 years old   Male                          Yes
# 2            NaN                NaN    NaN                          NaN
# 3   9 - 12 hours  35 - 44 years old   Male                          Yes
# 4  Over 12 hours  18 - 24 years old   Male                          Yes
#
#                          stackoverflow_participation
# 0  I have never participated in Q&A on Stack Over...
# 1                    A few times per month or weekly
# 2                                                NaN
# 3                    A few times per month or weekly
# 4                Less than once per month or monthly

# %%
survey_res_flt.to_csv("../../Data/filtered/2018.csv", index=False)
