# %% [markdown]
# This notebook is used to extractor the necessary data for Salary Prediction from 2019 Stack Overflow Annual Developer Survey
#
# https://insights.stackoverflow.com/survey

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# NOTE: Make sure **Data/source/** folder has the survey data downloaded using **Scripts/download_survey_data.py --all** script

# %% [markdown]
# ### 2018 Stack Overflow User Survey

# %%
survey_res = pd.read_csv("../../Data/source/2019.csv", sep=",", encoding='Latin-1', low_memory=False)

# %%
print(f"Number of responses to the survey in 2019: {survey_res.shape[0]}")
# Out:
# Number of responses to the survey in 2019: 88883

# %%
survey_res.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
# Extract the Country 
survey_res_flt = pd.DataFrame()
survey_res_flt["country"] = survey_res["Country"]

# Extract student information 
survey_res_flt["student"] = survey_res["Student"]

# Extract employment status
survey_res_flt["employment_status"] = survey_res["Employment"]

# Extract education background information
survey_res_flt["formal_education"] = survey_res["EdLevel"]

# Extract company size ~ Number of developers
survey_res_flt["company_size"] = survey_res["OrgSize"]

# Extract occupation 
survey_res_flt["occupation"] = survey_res["DevType"]

# Extract years of IT/programing experience
survey_res_flt["IT_experience_in_years"] = survey_res["YearsCodePro"]

# Extract job satisfaction 
survey_res_flt["job_satisfaction"] = survey_res["JobSat"]

# Extract compensation
survey_res_flt["compensation"] = survey_res["ConvertedComp"]

# Extract programming language/technology 
survey_res_flt["proficient_languages"] = survey_res["LanguageWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract programming language/technology 
survey_res_flt["database_worked_on"] = survey_res["DatabaseWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract programming language/technology 
survey_res_flt["platform_worked_on"] = survey_res["PlatformWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract programming language/technology 
survey_res_flt["framework_worked_on"] = survey_res["WebFrameWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract the desktop operating system used 
survey_res_flt["desktop_OS"] = survey_res["OpSys"]

# Extract time spent on work hours per week
survey_res_flt["work_hours_weekly"] = survey_res["WorkWeekHrs"]

# Extract Age
survey_res_flt["age"] = survey_res["Age"]

#Extract gender
survey_res_flt["gender"] = survey_res["Gender"]

# %%
# Extract stackoverflow reputation 
survey_res_flt["stackoverflow_account_holder"] = survey_res["SOAccount"]

# Extract stackoverflow reputation 
survey_res_flt["stackoverflow_participation"] = survey_res["SOPartFreq"]

# %%
survey_res_flt.head()
# Out:
#                   country         student  \
# 0          United Kingdom              No
# 1  Bosnia and Herzegovina  Yes, full-time
# 2                Thailand              No
# 3           United States              No
# 4                 Ukraine              No
#
#                         employment_status  \
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                     formal_education  \
# 0                          Primary/elementary school
# 1  Secondary school (e.g. American high school, G...
# 2         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 3         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 4         Bachelorâs degree (BA, BS, B.Eng., etc.)
#
#                company_size  \
# 0                       NaN
# 1                       NaN
# 2      100 to 499 employees
# ...

# %%
survey_res_flt.to_csv("../../Data/filtered/2019.csv", index=False)
