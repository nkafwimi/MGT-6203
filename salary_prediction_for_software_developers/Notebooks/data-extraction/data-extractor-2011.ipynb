# %% [markdown]
# This notebook is used to extractor the necessary data for Salary Prediction from 2011 Stack Overflow Annual Developer Survey
#
# https://insights.stackoverflow.com/survey

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# NOTE: Make sure **Data/source/** folder has the survey data downloaded using **Scripts/download_survey_data.py --all** script

# %% [markdown]
# # 2011 Stack Overflow User Survey

# %%
survey_res = pd.read_csv("../../Data/source/2011.csv", sep=",", encoding='Latin-1')

# %%
print(f"Number of responses to the survey in 2011: {survey_res.shape[0]-1}")
# Out:
# Number of responses to the survey in 2011: 2813

# %%
survey_res = survey_res.drop(0)
survey_res.head()
# Out:
#   What Country or Region do you live in?  \
# 1                                 Africa
# 2                           Other Europe
# 3                                  India
# 4                                Germany
# 5                             Other Asia
#
#   Which US State or Territory do you live in? How old are you?  \
# 1                                         NaN             < 20
# 2                                         NaN            25-29
# 3                                         NaN            25-29
# 4                                         NaN             < 20
# 5                                         NaN            35-39
#
#   How many years of IT/Programming experience do you have?  \
# 1                                                 <2
# 2                                              41310
# 3                                              41435
# 4                                              41310
# 5                                                 11
#
#   How would you best describe the industry you work in?  \
# 1                                         Consulting
# 2                                  Software Products
# 3                                  Software Products
# 4                            Foundation / Non-Profit
# 5                                  Software Products
#
#   Which best describes the size of your company?  \
# 1                                Start Up (1-25)
# 2                 Mature Small Business (25-100)
# 3                            Mid Sized (100-999)
# 4                                        Student
# 5                                Start Up (1-25)
#
#   Which of the following best describes your occupation?  \
# 1                          Web Application Developer
# 2                                  Server Programmer
# 3                                  Server Programmer
# 4                                            Student
# 5              Executive (VP of Eng, CTO, CIO, etc.)
#
#   How likely is it that a recommendation you make will be acted upon?  \
# 1                             Not in a million years
# 2                          It's been known to happen
# 3                   Unless it's stoopid it gets done
# 4                          It's been known to happen
# 5                                   I run this place
#
#   What is your involvement in purchasing? You can choose more than 1.  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                         Influencer
#
#   Unnamed: 9  ... Unnamed: 55 Unnamed: 56    Unnamed: 57 Unnamed: 58  \
# 1        NaN  ...         NaN         NaN            NaN         NaN
# 2        NaN  ...         NaN         NaN  Other netbook         NaN
# 3        NaN  ...         NaN         NaN            NaN         NaN
# 4        NaN  ...         NaN         NaN            NaN         NaN
# 5        NaN  ...         NaN         NaN            NaN         NaN
#
#   Unnamed: 59 Unnamed: 60          Unnamed: 61 Unnamed: 62  \
# 1         NaN         NaN                  NaN         NaN
# 2         NaN         NaN                  NaN         NaN
# 3         NaN         NaN                  NaN         NaN
# 4         NaN         Wii  Other gaming system         NaN
# 5        Xbox         NaN                  NaN         NaN
#
#   In the last 12 months, how much money have you spent on personal technology-related purchases?   \
# 1                                              <$100
# 2                                          $251-$500
# 3                                                NaN
# 4                                        $501-$1,000
# 5                                          $251-$500
#
#   Which of our sites do you frequent most?
# 1                                      NaN
# 2                           Stack Overflow
# 3                                      NaN
# 4                           Stack Overflow
# 5                           Stack Overflow
#
# [5 rows x 65 columns]

# %%
# Extract the Country 

survey_res_flt = pd.DataFrame()
survey_res_flt["country"] = survey_res["What Country or Region do you live in?"]

# Extract Age
survey_res_flt["age"] = survey_res["How old are you?"]

# Extract years of IT/programing experience
survey_res_flt["IT_experience_in_years"] = survey_res["How many years of IT/Programming experience do you have?"]

# Extract industry 
survey_res_flt["industry"] = survey_res["How would you best describe the industry you work in?"]

# Extract company size 
survey_res_flt["company_size"] = survey_res["Which best describes the size of your company?"]

# Extract occupation 
survey_res_flt["occupation"] = survey_res["Which of the following best describes your occupation?"]

# Extract Current project details
survey_res_flt["current_development_project"] = survey_res["What type of project are you developing?"]

# %%
# Extract programming language 

language_col_start = survey_res.columns.get_loc("Which languages are you proficient in?")

survey_res_flt["proficient_languages"] = (
    survey_res
    .iloc[:, language_col_start+1:language_col_start+13]
    .apply(lambda x: ",".join(x.astype(str)), axis = 1)
)

survey_res_flt["proficient_languages"] = [[pl for pl in pl_list.split(',') if pl != 'nan'] for pl_list in survey_res_flt['proficient_languages'].values.tolist()]

# %%
# Extract the desktop operating system used 
survey_res_flt["desktop_OS"] = survey_res["What operating system do you use the most?"]

# Extract job satisfaction 
survey_res_flt["job_satisfaction"] = survey_res["Please rate your job/career satisfaction"]

# Extract compensation
survey_res_flt["compensation"] = survey_res["Including bonus, what is your annual compensation in USD?"]

# %%
# Extract Product technology
product_tech_col_start = survey_res.columns.get_loc("Which technology products do you own? (You can choose more than one)")

survey_res_flt["product_technology"] = (
    survey_res
    .iloc[:, product_tech_col_start+1:product_tech_col_start+20]
    .apply(lambda x: ",".join(x.astype(str)), axis = 1)
)

survey_res_flt["product_technology"] = [[pt for pt in pt_list.split(',') if pt != 'nan'] for pt_list in survey_res_flt['product_technology'].values.tolist()]

# %%
survey_res_flt.head()
# Out:
#         country    age IT_experience_in_years                 industry  \
# 1        Africa   < 20                     <2               Consulting
# 2  Other Europe  25-29                  41310        Software Products
# 3         India  25-29                  41435        Software Products
# 4       Germany   < 20                  41310  Foundation / Non-Profit
# 5    Other Asia  35-39                     11        Software Products
#
#                      company_size                             occupation  \
# 1                 Start Up (1-25)              Web Application Developer
# 2  Mature Small Business (25-100)                      Server Programmer
# 3             Mid Sized (100-999)                      Server Programmer
# 4                         Student                                Student
# 5                 Start Up (1-25)  Executive (VP of Eng, CTO, CIO, etc.)
#
#   current_development_project                       proficient_languages  \
# 1                      Mobile                               [JavaScript]
# 2                  Enterprise                                   [SQL, C]
# 3                        SaaS                          [JavaScript, SQL]
# 4                       Other                                  [Haskell]
# 5                  Enterprise  [JavaScript, CSS, PHP, SQL, C++, C, Perl]
#
#   desktop_OS       job_satisfaction          compensation  \
# 1      Linux                    FML  Student / Unemployed
# 2  Windows 7      So happy it hurts                   NaN
# 3      Linux                    NaN                   NaN
# 4      Linux  I enjoy going to work  Student / Unemployed
# 5      Linux      It pays the bills    $80,000 - $100,000
#
#                                   product_technology
# 1                                            [<$100]
# 2         [Other netbook, $251-$500, Stack Overflow]
# 3                                                 []
# 4  [Regular Mobile Phone, Kindle, Wii, Other gami...
# 5  [Android, Regular Mobile Phone, Kindle, Xbox, ...

# %%
survey_res_flt.to_csv("../../Data/filtered/2011.csv", index=False)
