# %% [markdown]
# This notebook is used to extractor the necessary data for Salary Prediction from 2020 Stack Overflow Annual Developer Survey
#
# https://insights.stackoverflow.com/survey

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# NOTE: Make sure **Data/source/** folder has the survey data downloaded using **Scripts/download_survey_data.py --all** script

# %% [markdown]
# ### 2020 Stack Overflow User Survey

# %%
survey_res = pd.read_csv("../Data/source/2020.csv", sep=",", encoding='Latin-1', low_memory=False)

# %%
print(f"Number of responses to the survey in 2020: {survey_res.shape[0]}")
# Out:
# Number of responses to the survey in 2020: 64461

# %%
survey_res.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
#      CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 0   European Euro  ...  Neither easy nor difficult  Appropriate in length
# 1  Pound sterling  ...                         NaN                    NaN
# 2             NaN  ...  Neither easy nor difficult  Appropriate in length
# 3    Albanian lek  ...                         NaN                    NaN
# 4             NaN  ...                        Easy              Too short
#
#   Trans                                     UndergradMajor  \
# 0    No  Computer science, computer engineering, or sof...
# 1   NaN  Computer science, computer engineering, or sof...
# 2   NaN                                                NaN
# 3    No  Computer science, computer engineering, or sof...
# 4    No  Computer science, computer engineering, or sof...
#
#   WebframeDesireNextYear    WebframeWorkedWith  \
# 0           ASP.NET Core  ASP.NET;ASP.NET Core
# 1                    NaN                   NaN
# 2                    NaN                   NaN
# 3                    NaN                   NaN
# 4   Django;Ruby on Rails         Ruby on Rails
#
#                               WelcomeChange WorkWeekHrs YearsCode YearsCodePro
# 0   Just as welcome now as I felt last year        50.0        36           27
# 1  Somewhat more welcome now than last year         NaN         7            4
# 2  Somewhat more welcome now than last year         NaN         4          NaN
# 3  Somewhat less welcome now than last year        40.0         7            4
# 4   Just as welcome now as I felt last year         NaN        15            8
#
# [5 rows x 61 columns]

# %%
# Extract the Country 
survey_res_flt = pd.DataFrame()
survey_res_flt["country"] = survey_res["Country"]

# Extract student information 
survey_res_flt["student"] = survey_res["MainBranch"]

# Extract employment status
survey_res_flt["employment_status"] = survey_res["Employment"]

# Extract employment status
survey_res_flt["formal_education"] = survey_res["EdLevel"]

# Extract company size ~ Number of developers
survey_res_flt["company_size"] = survey_res["Size"]

# Extract occupation 
survey_res_flt["occupation"] = survey_res["DevType"]

# Extract years of IT/programing experience
survey_res_flt["IT_experience_in_years"] = survey_res["YearsCode"]

# Extract years of IT/programing experience Professional
survey_res_flt["IT_experience_in_years_job"] = survey_res["YearsCodingPro"]

# Extract job satisfaction 
survey_res_flt["job_satisfaction"] = survey_res["JobSat"]

# Extract compensation
survey_res_flt["compensation"] = survey_res["CompTotal"]

# Extract programming language/technology 
survey_res_flt["proficient_languages"] = survey_res["LanguageWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract programming language/technology 
survey_res_flt["database_worked_on"] = survey_res["DatabaseWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract programming language/technology 
survey_res_flt["platform_worked_on"] = survey_res["PlatformWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract programming language/technology 
survey_res_flt["framework_worked_on"] = survey_res["WebframeWorkedWith"].apply(lambda x: x.split(";") if not isinstance(x, float) else x)

# Extract the desktop operating system used 
survey_res_flt["desktop_OS"] = survey_res["OpSys"]

# Extract time spent on work 
survey_res_flt["work_hours"] = survey_res["WorkWeekHrs"]

# Extract Age
survey_res_flt["age"] = survey_res["Age"]

#Extract gender
survey_res_flt["gender"] = survey_res["Gender"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CompanySize'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 15>()
#      12 survey_res_flt["formal_education"] = survey_res["EdLevel"]
#      14 # Extract company size ~ Number of developers
# ---> 15 survey_res_flt["company_size"] = survey_res["CompanySize"]
#      17 # Extract occupation
#      18 survey_res_flt["occupation"] = survey_res["DevType"]
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'CompanySize'

# %%
# Extract stackoverflow reputation 
survey_res_flt["stackoverflow_account_holder"] = survey_res["StackOverflowHasAccount"]

# Extract stackoverflow reputation 
survey_res_flt["stackoverflow_participation"] = survey_res["StackOverflowParticipate"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'StackOverflowHasAccount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 # Extract stackoverflow reputation
# ----> 2 survey_res_flt["stackoverflow_account_holder"] = survey_res["StackOverflowHasAccount"]
#       4 # Extract stackoverflow reputation
#       5 survey_res_flt["stackoverflow_participation"] = survey_res["StackOverflowParticipate"]
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'StackOverflowHasAccount'

# %%
survey_res_flt.head()
# Out:
#           country         student   employment_status  \
# 0           Kenya              No  Employed part-time
# 1  United Kingdom              No  Employed full-time
# 2   United States              No  Employed full-time
# 3   United States              No  Employed full-time
# 4    South Africa  Yes, part-time  Employed full-time
#
#                                     formal_education  \
# 0         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 1         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 2                                   Associate degree
# 3         Bachelorâs degree (BA, BS, B.Eng., etc.)
# 4  Some college/university study without earning ...
#
#                company_size  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                           occupation IT_experience_in_years  \
# 0                               Full-stack developer              3-5 years
# 1  Database administrator;DevOps specialist;Full-...            18-20 years
# 2           Engineering manager;Full-stack developer              6-8 years
# 3                               Full-stack developer            12-14 years
# 4  Data or business analyst;Desktop or enterprise...              0-2 years
#
#                      job_satisfaction  compensation  \
# 0                 Extremely satisfied           NaN
# 1             Moderately dissatisfied       70841.0
# 2                Moderately satisfied           NaN
# 3  Neither satisfied nor dissatisfied           NaN
# 4                  Slightly satisfied       21426.0
#
#                                 proficient_languages  \
# 0                    [JavaScript, Python, HTML, CSS]
# 1                   [JavaScript, Python, Bash/Shell]
# 2                                                NaN
# 3  [C#, JavaScript, SQL, TypeScript, HTML, CSS, B...
# 4         [C, C++, Java, Matlab, R, SQL, Bash/Shell]
#
#                                   database_worked_on  \
# 0  [Redis, SQL Server, MySQL, PostgreSQL, Amazon ...
# 1                     [Redis, PostgreSQL, Memcached]
# 2                                                NaN
# 3  [SQL Server, Microsoft Azure (Tables, CosmosDB...
# 4          [SQL Server, PostgreSQL, Oracle, IBM Db2]
#
#                      platform_worked_on framework_worked_on   desktop_OS  \
# 0         [AWS, Azure, Linux, Firebase]     [Django, React]  Linux-based
# 1                               [Linux]            [Django]  Linux-based
# 2                                   NaN                 NaN          NaN
# 3                               [Azure]                 NaN      Windows
# 4  [Arduino, Windows Desktop or Server]                 NaN      Windows
#
#       work_hours                age gender stackoverflow_account_holder  \
# 0   9 - 12 hours  25 - 34 years old   Male                          Yes
# 1    5 - 8 hours  35 - 44 years old   Male                          Yes
# 2            NaN                NaN    NaN                          NaN
# 3   9 - 12 hours  35 - 44 years old   Male                          Yes
# 4  Over 12 hours  18 - 24 years old   Male                          Yes
#
#                          stackoverflow_participation
# 0  I have never participated in Q&A on Stack Over...
# 1                    A few times per month or weekly
# 2                                                NaN
# 3                    A few times per month or weekly
# 4                Less than once per month or monthly

# %%
survey_res_flt.to_csv("../Data/filtered/2020.csv", index=False)
